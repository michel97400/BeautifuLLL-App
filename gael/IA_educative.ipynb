# %%
import os
from IPython.core.magic import register_line_magic
 #Récupèrelemotdepassedepuislavariabled'environnement
password = os.environ.get("MYSQL_PASSWORD")
 #Vérifiequelemotdepasseestbienrécupéré
if password is None:
    raiseValueError("La variables d'environnement MYSQL_PASSWORD n'est pas définie!")
connection_string= f"mysql+pymysql://root:{password}@localhost:3306"
 #Rechargel'extensionSQL
# %reload_ext sql
 #ConnecteàMySQL
# %sql $connection_string
# Out:
# Traceback (most recent call last):
#   File "c:\Users\Apprenant\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\engine\base.py", line 143, in __init__
#     self._dbapi_connection = engine.raw_connection()
#                              ~~~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\Apprenant\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\engine\base.py", line 3301, in raw_connection
#     return self.pool.connect()
#            ~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\Apprenant\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\pool\base.py", line 447, in connect
#     return _ConnectionFairy._checkout(self)
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "c:\Users\Apprenant\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\pool\base.py", line 1264, in _checkout
#     fairy = _ConnectionRecord.checkout(pool)
#   File "c:\Users\Apprenant\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\pool\base.py", line 711, in checkout
#     rec = pool._do_get()
#   File "c:\Users\Apprenant\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\pool\impl.py", line 177, in _do_get
#     with util.safe_reraise():
#          ~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\Apprenant\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\util\langhelpers.py", line 224, in __exit__
#     raise exc_value.with_traceback(exc_tb)
#   File "c:\Users\Apprenant\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\pool\impl.py", line 175, in _do_get
#     return self._create_connection()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\Apprenant\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\pool\base.py", line 388, in _create_connection
#     return _ConnectionRecord(self)
#   File "c:\Users\Apprenant\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\pool\base.py", line 673, in __init__
#     self.__connect()
#     ~~~~~~~~~~~~~~^^
#   File "c:\Users\Apprenant\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\pool\base.py", line 899, in __connect
#     with util.safe_reraise():
#          ~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\Apprenant\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\util\langhelpers.py", line 224, in __exit__
#     raise exc_value.with_traceback(exc_tb)
#   File "c:\Users\Apprenant\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\pool\base.py", line 895, in __connect
#     self.dbapi_connection = connection = pool._invoke_creator(self)
#                                          ~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "c:\Users\Apprenant\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\engine\create.py", line 661, in connect
#     return dialect.connect(*cargs, **cparams)
#            ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Apprenant\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\engine\default.py", line 629, in connect
#     return self.loaded_dbapi.connect(*cargs, **cparams)  # type: ignore[no-any-return]  # NOQA: E501
#            ~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Apprenant\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymysql\connections.py", line 365, in __init__
#     self.connect()
#     ~~~~~~~~~~~~^^
#   File "c:\Users\Apprenant\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymysql\connections.py", line 681, in connect
#     self._request_authentication()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\Apprenant\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymysql\connections.py", line 958, in _request_authentication
#     auth_packet = self._read_packet()
#   File "c:\Users\Apprenant\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymysql\connections.py", line 782, in _read_packet
#     packet.raise_for_error()
#     ~~~~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\Apprenant\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymysql\protocol.py", line 219, in raise_for_error
#     err.raise_mysql_exception(self._data)
#     ~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
#   File "c:\Users\Apprenant\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymysql\err.py", line 150, in raise_mysql_exception
#     raise errorclass(errno, errval)
# pymysql.err.OperationalError: (1045, "Access denied for user 'root'@'localhost' (using password: YES)")
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\Users\Apprenant\AppData\Local\Programs\Python\Python313\Lib\site-packages\sql\magic.py", line 196, in execute
#     conn = sql.connection.Connection.set(
#         connect_str,
#     ...<2 lines>...
#         creator=args.creator,
#     )
#   File "c:\Users\Apprenant\AppData\Local\Programs\Python\Python313\Lib\site-packages\sql\connection.py", line 70, in set
#     cls.current = existing or Connection(descriptor, connect_args, creator)
#                               ~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Apprenant\AppData\Local\Programs\Python\Python313\Lib\site-packages\sql\connection.py", line 55, in __init__
#     self.internal_connection = engine.connect()
#                                ~~~~~~~~~~~~~~^^
#   File "c:\Users\Apprenant\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\engine\base.py", line 3277, in connect
#     return self._connection_cls(self)
#            ~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "c:\Users\Apprenant\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\engine\base.py", line 145, in __init__
#     Connection._handle_dbapi_exception_noconnection(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         err, dialect, engine
#         ^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "c:\Users\Apprenant\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\engine\base.py", line 2440, in _handle_dbapi_exception_noconnection
#     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#   File "c:\Users\Apprenant\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\engine\base.py", line 143, in __init__
#     self._dbapi_connection = engine.raw_connection()
#                              ~~~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\Apprenant\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\engine\base.py", line 3301, in raw_connection
#     return self.pool.connect()
#            ~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\Apprenant\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\pool\base.py", line 447, in connect
#     return _ConnectionFairy._checkout(self)
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "c:\Users\Apprenant\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\pool\base.py", line 1264, in _checkout
#     fairy = _ConnectionRecord.checkout(pool)
#   File "c:\Users\Apprenant\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\pool\base.py", line 711, in checkout
#     rec = pool._do_get()
#   File "c:\Users\Apprenant\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\pool\impl.py", line 177, in _do_get
#     with util.safe_reraise():
#          ~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\Apprenant\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\util\langhelpers.py", line 224, in __exit__
#     raise exc_value.with_traceback(exc_tb)
#   File "c:\Users\Apprenant\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\pool\impl.py", line 175, in _do_get
#     return self._create_connection()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\Apprenant\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\pool\base.py", line 388, in _create_connection
#     return _ConnectionRecord(self)
#   File "c:\Users\Apprenant\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\pool\base.py", line 673, in __init__
#     self.__connect()
#     ~~~~~~~~~~~~~~^^
#   File "c:\Users\Apprenant\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\pool\base.py", line 899, in __connect
#     with util.safe_reraise():
#          ~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\Apprenant\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\util\langhelpers.py", line 224, in __exit__
#     raise exc_value.with_traceback(exc_tb)
#   File "c:\Users\Apprenant\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\pool\base.py", line 895, in __connect
#     self.dbapi_connection = connection = pool._invoke_creator(self)
#                                          ~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "c:\Users\Apprenant\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\engine\create.py", line 661, in connect
#     return dialect.connect(*cargs, **cparams)
#            ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Apprenant\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\engine\default.py", line 629, in connect
#     return self.loaded_dbapi.connect(*cargs, **cparams)  # type: ignore[no-any-return]  # NOQA: E501
#            ~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Apprenant\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymysql\connections.py", line 365, in __init__
#     self.connect()
#     ~~~~~~~~~~~~^^
#   File "c:\Users\Apprenant\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymysql\connections.py", line 681, in connect
#     self._request_authentication()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\Apprenant\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymysql\connections.py", line 958, in _request_authentication
#     auth_packet = self._read_packet()
#   File "c:\Users\Apprenant\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymysql\connections.py", line 782, in _read_packet
#     packet.raise_for_error()
#     ~~~~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\Apprenant\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymysql\protocol.py", line 219, in raise_for_error
#     err.raise_mysql_exception(self._data)
#     ~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
#   File "c:\Users\Apprenant\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymysql\err.py", line 150, in raise_mysql_exception
#     raise errorclass(errno, errval)
# sqlalchemy.exc.OperationalError: (pymysql.err.OperationalError) (1045, "Access denied for user 'root'@'localhost' (using password: YES)")
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
#
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys(['mysql+pymysql://root:***@localhost:3306'])

# %%
# %%sql
#
# # --Création de la base
# CREATE DATABASE IF NOT EXISTS ia_educative;
# USE ia_educative;
#
# #  --Suppression des tables si elles existent déjà
#
# DROP TABLE IF EXISTS role;
# DROP TABLE IF EXISTS matieres;
# DROP TABLE IF EXISTS niveau;
# DROP TABLE IF EXISTS etudiants;
# DROP TABLE IF EXISTS agent;
# DROP TABLE IF EXISTS session_conversation;
# DROP TABLE IF EXISTS message;
#
# # --Création des tables
# CREATE TABLE role(
#    id_role VARCHAR(50),
#    nom_role VARCHAR(50) NOT NULL,
#    PRIMARY KEY(id_role)
# );
#
# CREATE TABLE matieres(
#    id_matieres VARCHAR(50),
#    nom_matieres VARCHAR(50) NOT NULL,
#    description_matiere VARCHAR(50),
#    PRIMARY KEY(id_matieres)
# );
#
# CREATE TABLE niveau(
#    id_niveau VARCHAR(50),
#    libelle_niveau VARCHAR(50),
#    PRIMARY KEY(id_niveau)
# );
#
# CREATE TABLE etudiants(
#    id_users VARCHAR(50),
#    nom VARCHAR(50) NOT NULL,
#    prenom VARCHAR(50) NOT NULL,
#    email VARCHAR(50) NOT NULL,
#    avatar VARCHAR(50),
#    passwordhash VARCHAR(50) NOT NULL,
#    date_inscription DATETIME NOT NULL,
#    consentement_rgpd DATETIME NOT NULL,
#    id_niveau VARCHAR(50) NOT NULL,
#    id_role VARCHAR(50) NOT NULL,
#    PRIMARY KEY(id_users),
#    UNIQUE(email),
#    FOREIGN KEY(id_niveau) REFERENCES niveau(id_niveau),
#    FOREIGN KEY(id_role) REFERENCES role(id_role)
# );
#
# CREATE TABLE agent(
#    id_agents VARCHAR(50),
#    nom_agent VARCHAR(50) NOT NULL,
#    type_agent VARCHAR(50) NOT NULL,
#    avatar_agent DATETIME,
#    est_actif BOOLEAN,
#    description VARCHAR(50),
#    date_creation DATETIME,
#    prompt_systeme VARCHAR(50),
#    id_matieres VARCHAR(50),
#    id_users VARCHAR(50) NOT NULL,
#    PRIMARY KEY(id_agents),
#    UNIQUE(nom_agent),
#    FOREIGN KEY(id_matieres) REFERENCES matieres(id_matieres),
#    FOREIGN KEY(id_users) REFERENCES etudiants(id_users)
# );
#
# CREATE TABLE session_conversation(
#    id_session VARCHAR(50),
#    date_heure_debut DATETIME NOT NULL,
#    duree_session TIME NOT NULL,
#    date_heure_fin DATETIME NOT NULL,
#    id_agents VARCHAR(50) NOT NULL,
#    id_users VARCHAR(50) NOT NULL,
#    PRIMARY KEY(id_session),
#    FOREIGN KEY(id_agents) REFERENCES agent(id_agents),
#    FOREIGN KEY(id_users) REFERENCES etudiants(id_users)
# );
#
# CREATE TABLE message(
#    id_message VARCHAR(50),
#    role VARCHAR(50),
#    contenu VARCHAR(50),
#    date_envoi DATETIME,
#    id_session VARCHAR(50) NOT NULL,
#    PRIMARY KEY(id_message),
#    FOREIGN KEY(id_session) REFERENCES session_conversation(id_session)
# );
# Out:
#  * mysql+pymysql://root:***@localhost:3306
# (pymysql.err.OperationalError) (2006, "MySQL server has gone away (ConnectionResetError(10054, 'Une connexion existante a dû être fermée par l’hôte distant', None, 10054, None))")
# [SQL: # --Création de la base
# CREATE DATABASE IF NOT EXISTS ia_educative;]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
